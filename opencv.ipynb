# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrayusaldi/Introduction-to-Computer-Vision/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to use opencv...**

# %% [markdown]
# install library, install di PC/Laptop local

# %%
#pip install opencv-python
#pip install opencv-contrib-python

# %% [markdown]
# Mounting drive

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cek versi opencv

# %%
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %% [markdown]
# Import library

# %%
import cv2
import numpy as np
import PIL 
import matplotlib.pyplot as plt
from PIL import Image 
from google.colab.patches import cv2_imshow
# %matplotlib inline


img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Pcd/gs.png') #read image, disini saya pakai logo dari G Collab
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950640EE0>

# %%
# Display the opencv image using matplotlib, image jadi biru karena format dari opencv adalah B,G,R (reverse dari R,G,B) dan matplotlib baca dari R,G,B
plt.imshow(img)
#plt.show()

# %% [markdown]
# **Resizing image**
# 1. Resizing to a specific height and width

# %%
height = 400  #tinggi jadi 400
width = 400   #lebar jadi 400
dimension = (width, height)
new_image = cv2.resize (img, dimension)
print("Original shape : ", img.shape)   #menampilkan ukuran awal
print("New shape : ", new_image.shape)
cv2_imshow(new_image)

## gambar telah berhasil diubah ukurannya menjadi 400x400
# Out:
# Original shape :  (225, 225, 3)
# New shape :  (400, 400, 3)
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F29506D6E50>

# %% [markdown]
# 2. Resizing to a specific height and width & Preserving the aspect ratio of the image

# %%
height = 400
width = 400
dimension = (width, height)
new_image = cv2.resize (img, dimension, interpolation=cv2.INTER_LINEAR)
print("Original shape : ", img.shape)
print("New shape : ", new_image.shape)
cv2_imshow(new_image)
# Out:
# Original shape :  (225, 225, 3)
# New shape :  (400, 400, 3)
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F2950510040>

# %% [markdown]
# 3. Resizing with a scalling factor

# %%
height = img.shape[0]
width = img.shape[1]

# kita mau ukuran gambarnya jadi 40% dari gambar original

scale_factor = 0.4 #=40%
new_height = int(height * scale_factor) # 300 * 0.4 = 960
new_height = int(width * scale_factor)  # 400 * 0.4 = 1536
dimension = (new_height, new_height)    # (960, 1536)
new_image = cv2.resize (img, dimension, interpolation=cv2.INTER_LINEAR)
print("Original shape : ", img.shape)
print("New shape : ", new_image.shape)
cv2_imshow(new_image)
# Out:
# Original shape :  (225, 225, 3)
# New shape :  (90, 90, 3)
# <PIL.Image.Image image mode=RGB size=90x90 at 0x7F295052CE80>

# %% [markdown]
# **Konversi warna**
#   1. konversi ke Grayscale

# %%
img_grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=225x225 at 0x7F2950561D90>

# %% [markdown]
#   2. Konversi ke HSV

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2_imshow(img_hsv)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950509700>

# %% [markdown]
# **Mengatur brightness dan contrast dari images**
#
# *   Alpha value untuk controll contrast, range = 1.0-3.0
# *   Beta value untuk controll brightness, range = 0-100

# %%
def brightness_contrast(img, alpha = 0, beta = 0):
    # alpha contrast control (1.0-3.0)
    # beta brightness control (0-100)

    adjusted = cv2.convertScaleAbs(img, alpha = alpha, beta  = beta)
    return adjusted

# %% [markdown]
# **Peningkatan contrast**

# %%
new_img = brightness_contrast(img, 1, 50) #1 adalah Alpha value dan 50 adalah Beta value

print("Original image")
cv2_imshow(img)

print("\n")

print("Gambar dengan brightness yang ditingkatkan")
cv2_imshow(new_img)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950510040>
# Gambar dengan brightness yang ditingkatkan
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F29506D6DF0>

# %%
new_img = brightness_contrast(img, 2, 0)  #2 adalah Alpha value dan 0 adalah Beta value

print("Original image")
cv2_imshow(img)
cv2.waitKey(0)

print("\n")

print("gambar dengan kontras yang ditingkatkan")
cv2_imshow(new_img)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F29505102E0>
# gambar dengan kontras yang ditingkatkan
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950640A90>

# %% [markdown]
# **Membuat gambar menjadi blur**
#
# Gaussian Blur

# %%
# menerapkan filter Gaussian dengan ukuran kernel 5x5 & 15x15
blurred1 = cv2.GaussianBlur(img, (5, 5), 0)
blurred2 = cv2.GaussianBlur(img, (15, 15), 0)

# menampilkan gambar asli dan yang telah di-blur
print("Original image")
cv2_imshow(img)

print("\n")

print("Output gaussian blur pertama (5, 5 dan sigma 0)")
cv2_imshow(blurred1)

print("\n")

print("Output gaussian blur kedua (15, 15 dan sigma 0)")
cv2_imshow(blurred2)
# Out:
# Original image
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950530370>
# Output gaussian blur pertama (5, 5 dan sigma 0)
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950530400>
# Output gaussian blur kedua (15, 15 dan sigma 0)
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F2950530370>

# %% [markdown]
# **Gambar sebagai multidimensional arrays**

# %%
print("Matrix Gambar : \n", img)
print(type(img))
# Out:
# Matrix Gambar :
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [219 178 171]
#   ...
#   [201 127 115]
#   [253 251 250]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [243 228 226]
#   [180  77  56]
#   ...
#   [182  70  48]
#   [217 186 181]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [230 209 205]
#   ...
#   [217 186 181]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# <class 'numpy.ndarray'>

# %%
print("Bentuk gambar asli ", img.shape)
print("Ukuran gambar asli ", img.size)
print("\n")
print("Bentuk gambar grayscale ", img_grayscale.shape)
print("Ukuran gambar grayscale ", img_grayscale.size)
# Out:
# Bentuk gambar asli  (225, 225, 3)
# Ukuran gambar asli  151875
#
#
# Bentuk gambar grayscale  (225, 225)
# Ukuran gambar grayscale  50625

# %% [markdown]
# **Region of Interest as roi**
#
# simple nya memfokuskan pada bagian gambar yang diinginkan saja.

# %%
roi=img[30:200, 50:300] 
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=RGB size=175x170 at 0x7F2950510F70>
